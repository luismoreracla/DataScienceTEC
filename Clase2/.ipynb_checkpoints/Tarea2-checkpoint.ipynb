# %% [markdown]
# # Tarea 2
# ## Funcionalidades básicas de Pandas
# ### Luis Morera Claramunt

# %% [markdown]
# Se trabaja con un dataset de accidentes de vuelos

# %%
#Se importan las librerias necesarias
import pandas as pd
import numpy as np

# %% [markdown]
# Se lee el archivo csv del dataset

# %%
db = pd.read_csv('https://raw.githubusercontent.com/luismoreracla/DataScienceTEC/master/Clase2/planecrashinfo_20181121001952.csv')
print(db.head(20))
# Out:
#                   date     time                            location  \
# 0   September 17, 1908    17:18                 Fort Myer, Virginia
# 1   September 07, 1909        ?             Juvisy-sur-Orge, France
# 2        July 12, 1912    06:30           Atlantic City, New Jersey
# 3      August 06, 1913        ?  Victoria, British Columbia, Canada
# 4   September 09, 1913  c 18:30                  Over the North Sea
# 5     October 17, 1913  c 10:30          Near Johannisthal, Germany
# 6       March 05, 1915  c 01:00                     Tienen, Belgium
# 7   September 03, 1915  c 15:20               Off Cuxhaven, Germany
# 8        July 28, 1916        ?               Near Jambol, Bulgeria
# 9   September 24, 1916  c 01:00                 Billericay, England
# 10    October 01, 1916  c 23:45                Potters Bar, England
# 11   November 21, 1916        ?                      Mainz, Germany
# 12   November 28, 1916  c 23:45        Off West Hartlepool, England
# ...

# %% [markdown]
# Primero se usa el comando .describe() para obtener información estadística general del dataset

# %%
db.describe()
# Out:
#                      date  time        location  operator flight_no route  \
# count                5783  5783            5783      5783      5783  5783
# unique               5213  1346            4715      2821       890  3875
# top     February 28, 1973     ?  Moscow, Russia  Aeroflot         ?     ?
# freq                    4  2108              18       260      4436  1494
#
#              ac_type registration cn_ln                      aboard  \
# count           5783         5783  5783                        5783
# unique          2742         5394  4149                        1042
# top     Douglas DC-3            ?     ?  2   (passengers:0  crew:2)
# freq             341          352  1207                         236
#
#                         fatalities ground summary
# count                         5783   5783    5783
# unique                         917     54    5368
# top     1   (passengers:0  crew:1)      0       ?
# freq                           288   5474     231

# %% [markdown]
# Para conocer el tamaño del data set se utiliza .shape

# %%
db.shape
# Out:
# (5783, 13)

# %% [markdown]
# Para ver los primeros x elementos del dataset se utiliza head(x).
#
# Siendo x un número entero.

# %%
db.head(5)
# Out:
#                  date     time                            location  \
# 0  September 17, 1908    17:18                 Fort Myer, Virginia
# 1  September 07, 1909        ?             Juvisy-sur-Orge, France
# 2       July 12, 1912    06:30           Atlantic City, New Jersey
# 3     August 06, 1913        ?  Victoria, British Columbia, Canada
# 4  September 09, 1913  c 18:30                  Over the North Sea
#
#                  operator flight_no          route                 ac_type  \
# 0    Military - U.S. Army         ?  Demonstration        Wright Flyer III
# 1                       ?         ?       Air show          Wright Byplane
# 2    Military - U.S. Navy         ?    Test flight               Dirigible
# 3                 Private         ?              ?        Curtiss seaplane
# 4  Military - German Navy         ?              ?  Zeppelin L-1 (airship)
#
#   registration cn_ln                       aboard  \
# 0            ?     1   2   (passengers:1  crew:1)
# ...

# %% [markdown]
# Para ver los primeros x elementos del dataset se utiliza tail(x).
#
# Siendo x un número entero.

# %%
db.tail(5)
# Out:
#                     date  time                location             operator  \
# 5778       July 10, 2018  0744  Pretoria, South Africa            Rovos Air
# 5779     August 04, 2018  1655      Flims, Switzerland               Ju Air
# 5780  September 28, 2018  1010       Chuuk, Micronesia          Air Niugini
# 5781    October 29, 2018  0631  Off Jakarta, Indonesia             Lion Air
# 5782   November 06, 2018  0253      Georgetown, Guyana  Fly Jamaica Airways
#
#      flight_no                     route           ac_type registration  \
# 5778         ?               Test Flight    Convair CV-340       ZS-BRV
# 5779         ?       Locorno - Dubendorf     Junkers JU-52       HB-HOT
# 5780         ?           Pohnpei - Chuuk    Boeing 737-8BK       P2-PXE
# 5781       610  Jakarta - Pangkal Pinang  Boeing 737-MAX 8       PK-LQP
# 5782         ?      Georgetown - Toronto    Boeing 757-N23       N524AT
#
#            cn_ln                          aboard  \
# ...

# %% [markdown]
# Para ver las columnas del dataset se utiliza .columns y con .dtypes se conoce el tipo de dato

# %%
db.columns
db.dtypes
# Out:
# date            object
# time            object
# location        object
# operator        object
# flight_no       object
# route           object
# ac_type         object
# registration    object
# cn_ln           object
# aboard          object
# fatalities      object
# ground          object
# summary         object
# dtype: object

# %% [markdown]
# Para ver si el set de datos tiene un índice asociado se utiliza .index.values

# %%
db.index.values
# Out:
# array([   0,    1,    2, ..., 5780, 5781, 5782])

# %% [markdown]
# Para eliminar columnas dentro del set de datos se usa .drop

# %%
# Out:
# Index(['date', 'time', 'location', 'operator', 'flight_no', 'route',
#        'registration', 'aboard', 'fatalities', 'summary'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-9870364bfa70> in <module>
# ----> 1 cols_to_eliminate = db[['ac_type', 'ground', 'cn_ln']]
#       2 print(cols_to_eliminate)
#
# ~/miniconda3/envs/py3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/miniconda3/envs/py3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...
