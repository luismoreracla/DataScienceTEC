# %%
import numpy as np
import pandas as pd
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-5dbe3a555ca6> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
data = pd.read_csv("https://raw.githubusercontent.com/fmezacr/DataScienceTEC/master/Clase2/titanic.csv")

# %%
data.shape
# Out:
# (891, 12)

# %%
cols_to_use = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare','Survived']
data = data[cols_to_use]

# %%
data.isnull().values.any()
# Out:
# True

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (714, 7)

# %% [markdown]
# # Modelo de Aprendizaje Simple

# %%
data['Sex'] = data['Sex'].replace({'male' : 0, 'female' : 1})

# %%
features = data[['Sex', 'Age', 'Fare']]

# %%
labels = data['Survived']

# %%
data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Survived
# 0       3    0  22.0      1      0   7.2500         0
# 1       1    1  38.0      1      0  71.2833         1
# 2       3    1  26.0      0      0   7.9250         1
# 3       1    1  35.0      1      0  53.1000         1
# 4       3    0  35.0      0      0   8.0500         0

# %%
features.head()
# Out:
#    Sex   Age     Fare
# 0    0  22.0   7.2500
# 1    1  38.0  71.2833
# 2    1  26.0   7.9250
# 3    1  35.0  53.1000
# 4    0  35.0   8.0500

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(features, labels, random_state = 13)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeModel = DecisionTreeClassifier(max_depth = 3)

# %%
DecisionTreeModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import accuracy_score

# %%
y_predict = DecisionTreeModel.predict(X_test)

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.7932960893854749

# %%
from sklearn.tree import export_graphviz
export_graphviz(DecisionTreeModel, out_file='simple_tree.dot', feature_names=features.columns,impurity=False,class_names=['Not survived','Survived'],filled=True)
from subprocess import call
call(['dot', '-T', 'png', 'simple_tree.dot', '-o', 'simple_tree.png'])
# Out:
# 0

# %%
from IPython.display import Image
Image("simple_tree.png")

# %% [markdown]
# # Random Forest
#
# Es un conjunto de arboles de decision distintos que entre todos minimizan el overfitting, creados de manera aleatoria.
#
# Es de categoria de ensamble

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RandomForestModel = RandomForestClassifier(min_samples_leaf=3, min_samples_split=20, n_estimators=500, max_depth=None, random_state=10)

# %%
RandomForestModel.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=20,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=10, verbose=0,
#                        warm_start=False)

# %%
y_predict=RandomForestModel.predict(X_test)

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.8324022346368715

# %%
importances = pd.DataFrame({'feature': X_train.columns, 'importance':RandomForestModel.feature_importances_})

# %%
importances = importances.sort_values('importance', ascending = False).set_index('feature')

# %%
importances.head(9)
# Out:
#          importance
# feature
# Sex        0.401980
# Fare       0.370131
# Age        0.227889

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
importances.plot.bar()

# %% [markdown]
# Tres pasos de cualquer algoritmo de ML
#
# 1. Modelo matematico
# 2. critetio de optimizacion
# 3. Construccion del modelo

# %%
import torch

# %%
x = torch.tensor(3.)
w = torch.tensor(4., requires_grad=True) #Para habilitar las derivadas parciales
b = torch.tensor(3., requires_grad=True)

# %%
y=w*x+b

# %%
y
# Out:
# tensor(15., grad_fn=<AddBackward0>)

# %%
#Para calcular las derivadas parciales
y.backward()

# %%
print('dy/dw:', w.grad)
print('dy/db:', b.grad)
# Out:
# dy/dw: tensor(3.)
# dy/db: tensor(1.)

# %% [markdown]
# Region | Temp (F) | Rain (mm) | Hum (%) | Apples (ton) | Oranges (ton)
# ------------ | ------------- | ------------- | ------------- | ------------- | -------------
# Kanto | 73 | 67 | 43 | 56 | 70
# Johto | 91 | 88 | 64 | 81 | 101
# Hoenn | 87 | 134 | 58 | 119 | 133
# Sinnoh | 102 | 43 | 37 | 22 | 37
# Unova | 69 | 96 | 70 | 103 | 119

# %%
#con @ hago multiplicacion de matrices
def model(X):
    return x @ x.t() + b

# %%
preds = model(inputs)
print(preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-c6db141153ac> in <module>
# ----> 1 preds = model(inputs)
#       2 print(preds)
#
# NameError: name 'inputs' is not defined
